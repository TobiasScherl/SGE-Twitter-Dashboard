# %% [markdown]
# ## Data preparation

# %%
#Import necessary libraries
import pandas as pd
import numpy as np 
import re
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from deep_translator import GoogleTranslator
import ast

# %%
#Read in csv file with scraped Tweets into pandas dataframe
df = pd.read_csv(r'SGE_collected',header=None)

# %%
#Discover dataframe 
#=> missing column names
#=> some characters included that can be removed in the columns with indexes 1 and 2 for example
df.head()
# Out:
#                            0  \
# 0  2023-02-08 19:21:35+00:00
# 1  2023-02-08 19:21:12+00:00
# 2  2023-02-08 19:20:38+00:00
# 3  2023-02-08 19:20:24+00:00
# 4  2023-02-08 19:19:38+00:00
#
#                                                    1             2  \
# 0  b'@EduardoSGE @sge_ge habe, die meinen Magen/D...  b'Anna_scxl'
# 1  b'Eintracht hat das Derby gewonnen und die Sta...    b'SGEagle'
# 2  b'@iamdardann @lysander_sge 40er war echt brut...     b'sge_94'
# 3  b'@EduardoSGE @sge_ge Ach das soll diese Sorge...  b'Anna_scxl'
# 4  b'R.I.P. Friedel Lutz, hier 3/2018 mit Dieter ...   b'fisPeppi'
#
#                                    3
# 0   b'Manchmal Hessen, oft Hannover'
# 1  b'Nordrhein-Westfalen, Deutschla'
# 2                                b''
# 3   b'Manchmal Hessen, oft Hannover'
# 4                  b'Frankfurt a.M.'

# %%
#Get length of dataframe
len(df)
# Out:
# 14549

# %%
#Rename columns of the dataframe
df.columns = ["Date", "Tweet", "User", "Location"]

# %%
#Decode tweet column to utf-8
df['tweet'] = df['Tweet'].apply(ast.literal_eval).str.decode("utf-8")

# %%
#Create datetime column time from column Date
df['time'] = pd.to_datetime(df['Date'])

# %%
#Create Date column Date from datetime column time
df['Date'] = pd.to_datetime(df['time']).dt.date

# %%
#Get weekday, Hour and Minute columns
df['weekday'] = df['time'].dt.dayofweek
df['Hour'] = df['time'].dt.hour
df['Minute'] = df['time'].dt.minute

# %%
#Dataframe now looks like this
df.head()
# Out:
#          Date                                              Tweet  \
# 0  2023-02-08  b'@EduardoSGE @sge_ge habe, die meinen Magen/D...
# 1  2023-02-08  b'Eintracht hat das Derby gewonnen und die Sta...
# 2  2023-02-08  b'@iamdardann @lysander_sge 40er war echt brut...
# 3  2023-02-08  b'@EduardoSGE @sge_ge Ach das soll diese Sorge...
# 4  2023-02-08  b'R.I.P. Friedel Lutz, hier 3/2018 mit Dieter ...
#
#            User                           Location  \
# 0  b'Anna_scxl'   b'Manchmal Hessen, oft Hannover'
# 1    b'SGEagle'  b'Nordrhein-Westfalen, Deutschla'
# 2     b'sge_94'                                b''
# 3  b'Anna_scxl'   b'Manchmal Hessen, oft Hannover'
# 4   b'fisPeppi'                  b'Frankfurt a.M.'
#
#                                                tweet  \
# 0  @EduardoSGE @sge_ge habe, die meinen Magen/Dar...
# 1  Eintracht hat das Derby gewonnen und die Stadt...
# 2  @iamdardann @lysander_sge 40er war echt brutal...
# 3  @EduardoSGE @sge_ge Ach das soll diese Sorge s...
# 4  R.I.P. Friedel Lutz, hier 3/2018 mit Dieter St...
#
#                        time  weekday  Hour  Minute
# 0 2023-02-08 19:21:35+00:00        2    19      21
# 1 2023-02-08 19:21:12+00:00        2    19      21
# 2 2023-02-08 19:20:38+00:00        2    19      20
# 3 2023-02-08 19:20:24+00:00        2    19      20
# 4 2023-02-08 19:19:38+00:00        2    19      19

# %%
#Just take the results from 6th to 8th of February
df = df.loc[:'2023-02-05']
df
# Out:
#             Date                                              Tweet  \
# 0     2023-02-08  b'@EduardoSGE @sge_ge habe, die meinen Magen/D...
# 1     2023-02-08  b'Eintracht hat das Derby gewonnen und die Sta...
# 2     2023-02-08  b'@iamdardann @lysander_sge 40er war echt brut...
# 3     2023-02-08  b'@EduardoSGE @sge_ge Ach das soll diese Sorge...
# 4     2023-02-08  b'R.I.P. Friedel Lutz, hier 3/2018 mit Dieter ...
# ...          ...                                                ...
# 2019  2023-02-06  b'@SGE_Melli Ja schon aber trotzdem f\xc3\xbch...
# 2020  2023-02-06  b'@sensinho82 @SGEintracht1899 Musst du ehrlic...
# 2021  2023-02-06                     b'@Natascha_SGE Klingt gut :)'
# 2022  2023-02-06  b'@faznet Wenn er sich hinter dem Pr\xc3\xa4si...
# 2023  2023-02-06  b'@LT16616534 Das macht das Eintrachtlied "Sch...
#
#                  User                           Location  \
# 0        b'Anna_scxl'   b'Manchmal Hessen, oft Hannover'
# 1          b'SGEagle'  b'Nordrhein-Westfalen, Deutschla'
# 2           b'sge_94'                                b''
# 3        b'Anna_scxl'   b'Manchmal Hessen, oft Hannover'
# 4         b'fisPeppi'                  b'Frankfurt a.M.'
# ...               ...                                ...
# 2019  b'Natascha_SGE'                                b''
# 2020    b'EduardoSGE'           b'Im Herzen Von Europa '
# 2021   b'taunusabbel'  b'Frankfurt am Main, Deutschland'
# 2022    b'Schietweer'                                b''
# 2023       b'Daggi17'  b'Frankfurt am Main, Deutschland'
#
#                                                   tweet  \
# 0     @EduardoSGE @sge_ge habe, die meinen Magen/Dar...
# 1     Eintracht hat das Derby gewonnen und die Stadt...
# 2     @iamdardann @lysander_sge 40er war echt brutal...
# 3     @EduardoSGE @sge_ge Ach das soll diese Sorge s...
# 4     R.I.P. Friedel Lutz, hier 3/2018 mit Dieter St...
# ...                                                 ...
# 2019  @SGE_Melli Ja schon aber trotzdem fühlt man si...
# 2020  @sensinho82 @SGEintracht1899 Musst du ehrlich ...
# 2021                        @Natascha_SGE Klingt gut :)
# 2022  @faznet Wenn er sich hinter dem Präsidenten st...
# 2023  @LT16616534 Das macht das Eintrachtlied "Schwa...
#
#                           time  weekday  Hour  Minute
# 0    2023-02-08 19:21:35+00:00        2    19      21
# 1    2023-02-08 19:21:12+00:00        2    19      21
# 2    2023-02-08 19:20:38+00:00        2    19      20
# 3    2023-02-08 19:20:24+00:00        2    19      20
# 4    2023-02-08 19:19:38+00:00        2    19      19
# ...                        ...      ...   ...     ...
# 2019 2023-02-06 19:37:13+00:00        0    19      37
# 2020 2023-02-06 19:35:37+00:00        0    19      35
# 2021 2023-02-06 19:35:04+00:00        0    19      35
# 2022 2023-02-06 19:34:59+00:00        0    19      34
# 2023 2023-02-06 19:34:59+00:00        0    19      34
#
# [2024 rows x 9 columns]

# %%
#Unique values for column User in the dataframe
df['User'].unique()
# Out:
#        "b'CarseneW'", "b'Lodeir0'", "b'Omakoma243'", "b'comuniomagazin'",
#        "b'Frankfurtnativ'", "b'derfutti'", "b'JohnBalluff'",
#        "b'HansThalhoffer'", "b'Florian__SGE'", "b'DeanMchumphrey'",
#        "b'VertStabs'", "b'L89_BVB'", "b'FUSSBALL2000'", "b'_NoopIa'",
#        "b'BayernfcBoy'", "b'MauritsvKeulen'", "b'CMoffiziell'",
#        "b'aFCN1900'", "b'AlexOberhessen'", "b'AndreasAndy3131'",
#        "b'ScHooIbooy'", "b'blowndiffuser__'", "b'FasziFankurve'",
#        "b'SGE_okriMH'", "b'AntiFr0sch'", "b'hands__of__god'",
#        "b'DerekSplitt'", "b'StaedtlerLeon'", "b'ap_tweety'",
#        "b'KoelnCaphunter'", "b'Michael_2305'", "b'mattimerker'",
#        "b'DennisSGE1899'", "b'h96_fabii'", "b'sge_LE'", "b'elias_sge_'",
#        "b'mareWieMeer'", "b'USchhcSU'", "b'StefanHo10'", "b'sgeadler87'",
#        "b'Ickthumb'", "b'abolladura1'", "b'GG_SGE'", "b'xela_aw'",
#        "b'ichhassdasdigga'", "b'sge_bini'", "b'ZDFhessen'",
#        "b'Zambrine5'", "b'Literaturlounge'", "b'YDottyDAG'",
#        "b'JogivonEsch'", "b'FloBa1107'", "b'vjvnas'", "b'Oaiwbd8aiwb'",
#        "b'bowlenwanker'", "b'dtrunk90'", "b'geierswelt'", "b'stillbauer'",
#        "b'drjones05'", "b'robertschulz_mz'", "b'Miss_Teached'",
#        "b'Palleamo'", "b'ohne_o'", "b'23oliver01'", "b'schladd3'",
#        "b'tova1893'", "b'pogodi1899'", "b'Fitbiter'", "b'thomas_seibert'",
#        "b'MMountain0611'", "b'SGE_Spiesser'", "b'televisionaer'",
#        "b'Masl201290'", "b'eintr8memes'", "b'DdorfAntifa'",
#        "b'Peter_der_Bayer'", "b'herb_16'", "b'aloa5'",
#        "b'GiesekingUlrike'", "b'SIGermany'", "b'lJuur6s'",
#        "b'EberzJulia'", "b'ErnieSouchakFfm'", "b'SGE_Gonzo'",
#        "b'ol76025989'", "b'marceasyyy'", "b'i1m81'", "b'sge1993'",
#        "b'dirkmschmidt'", "b'JanzSkywalker'", "b'KoelschFisch'",
#        "b'bumbesje'", "b'skarabaeus99'", "b'HoWink'", "b'RUHR24Dortmund'",
#        "b'rr_sge'", "b'67rh'", "b'lisaar0o'", "b'Maxibrezel'",
#        "b'jtresbach'", "b'Exilems14'", "b'YeboahsZeuge'", "b'PStter'",
#        "b'_oliverpfister'", "b'sge_ler1981'", "b'AndiFrankfurt'",
#        "b'fynnwrldd'", "b'Sportpapst'", "b'joffer41'",
#        "b'MuellerDenisman'", "b'C7_black'", "b'wfritz56'",
#        "b'Fussballsassie'", "b'einwurf_org'", "b'MasterUrs'",
#        "b'ElisabethSchag2'", "b'RsselsheimerEc2'", "b'CurseMa76'",
#        "b'BechtelDominik'", "b'supadupa63'", "b'FSK__a'",
#        "b'JoeYadaYadaYada'", "b'Yanny24315740'", "b'einohrxxx'",
#        "b'MarcG_118'", "b'janosrek1'", "b'bet365DE'", "b'uberdenkerin'",
#        "b'adlermax13'", "b'SportslandAlice'", "b'BrahmaBullGER'",
#        "b'ddh_tm3'", "b'nikmac308'", "b'm_jendrischik'", "b'rvnptr99'",
#        "b'HubertGrundman1'", "b'tb_bier'", "b'goals__zone'",
#        "b'don_king_87'", "b'derleitwolf'", "b'helge_fitz'",
#        "b'melligottschalk'", "b'sunnyzedenowa'", "b'Daniel_49er'",
#        "b'Christavo_Fring'", "b'Juergens_Welt'", "b'LornerWerant'",
#        "b'priapos79'", "b'funkfuss'", "b'sami_arslan1903'", "b'SGERon81'",
#        "b'PKrmr'", "b'eintrachtp0wer'", "b'KarlAlBundy33'", "b'sirtobey'",
#        "b'SirSchaefer01'", "b'j_mndh'", "b'DomWaits'", "b'omadduxo'",
#        "b'rapidalexx'", "b'elde_vo'", "b'MikulaFfm'", "b'CasaBla326583'",
#        "b'Chillstrike'", "b'SimiHoppSwiss1'", "b'ceescpraat'",
#        "b'TiffyWally'", "b'Chris_76_SGE'", "b'diet_mar'",
#        "b'fussballmafiade'", "b'ich24486151'", "b'BeateEi'",
#        "b'dschwerthelm'", "b'Youssef_nas2'", "b'fresendelf1'",
#        "b'Silvic76'", "b'MaxAbera'", "b'TillVennemann'",
#        "b'Florian_Kabul'", "b'lenawithme'", "b'SophieS65319600'",
#        "b'krisschi'", "b'Blaze2be'", "b'niklasohneck'", "b'Main_zuhause'",
#        "b'thinkpositiv8'", "b'Xantalis24'", "b'LPOehrchen'",
#        "b'attabirb'", "b'irg3ndwaswann'", "b'DerSiggmann'", "b'Tigersge'",
#        "b'marsibau'", "b'RustledToTheMax'", "b'Lethalsuspect'",
#        "b'skysolo2111'", "b'DurstEbby'", "b'PatrickBartusc4'",
#        "b'Nurhierzumlese2'", "b'_leon_1964_'", "b'DiesDasDaniel'",
#        "b'SuperSebb'", "b'datJulsche'", "b'alaneggerts'",
#        "b'HalloServusGude'", "b'sge4ever1983'", "b'dnsstr1899'",
#        "b'mibundesliga'", "b'YvesEigentor'", "b'Ghor_12'",
#        "b'Florian20425024'", "b'jasonpeep2022'", "b'jmk1337'",
#        "b'dschalalabad'", "b'lalemarleen'", "b'Dieadler_br'",
#        "b'prof_horatio'", "b'tom6134'", "b'W_i_n_n_i'", "b'flam_boyan_t'",
#        "b'anxne_'", "b'_giannicosta'", "b'homohockeyensis'", "b'Qub3xx'",
#        "b'inki1987'", "b'AnnieMuc'", "b'Mxhler1'", "b'ElbeWWF'",
#        "b'Frosty2101'", "b'rena_8059'", "b'b_represent'", "b'simonsolus'",
#        "b'BEYER_SZN'", "b'TopSecret1904'", "b'finni20132'",
#        "b'athletespw'", "b'PaulBMG'", "b'EaglesSilki'", "b'_ZodiacAss_'",
#        "b'KokelMario'", "b'VfBtweeter'", "b'AQT_ExpoFNBR'", "b'wheelzab'",
#        "b'KickbaseKing'", "b'finesse2frenkie'", "b'copapalmieri'",
#        "b'Henrise2'", "b'CafeSandrine'", "b'SDittl'", "b'Gleichmutig'",
#        "b'kimosch46'", "b'lnnx_wtz'", "b'RenoRang'", "b'Tragi75'",
#        "b'SantiaManti'", "b'KevinHorneck'", "b'che666th70'", "b'rmcfsge'",
#        "b'holger3700'", "b'Chris_AO86'", "b'sge_christopher'",
#        "b'Densevilla94'", "b'j4n77_'", "b'FloMuth'", "b'Luwinenseeger'",
#        "b'Glubbpapa'", "b'svs1946'", "b'MC_Magic13'", "b'ItsMrHM'",
#        "b'90min_DE'", "b'Positano_31'", "b'Wxzify'", "b'thomasschwenk12'",
#        "b'laughingball'", "b'Optimausi'", "b'DeuBaPark'",
#        "b'alex13wetter'", "b'DrWetti'", "b'nwoods4now'", "b'EbmMarta'",
#        "b'eintrachtfan95'", "b'zTom10_'", "b'xGogo33'", "b'Ka_ti8165'",
#        "b'achimK15'", "b'VronskiB'", "b'frabue'", "b'bakunin316'",
#        "b'MichiT3103'", "b'kleingero'", "b'mabagus'", "b'almighty_de'",
#        "b'doctorschobbe'", "b'quiet_but_riot'", "b'WCR1978'",
#        "b'SGE_Kev431'", "b'ali5tair93'", "b'Tuffys_world'",
#        "b'alexander_sge'", "b'DutchFromThe5'", "b'Igoria99'",
#        "b'PW_1980_'", "b'FcspI'", "b'1Wellensittich'", "b'LeonGruen'",
#        "b'pokaltaenzer'", "b'Andrejnalin77'", "b'OtcPegasus'",
#        "b'meinsofa'", "b'JonasJjo'", "b'Kuwanafuraha'",
#        "b'FrechdachsTurbo'", "b'KrugerBine'", "b'SabineVonReth'",
#        "b'liavah1'", "b'h_neongrau'", "b'ottersteinchen'", "b'OddNixon'",
#        "b'levikrasnitz'", "b'ukw11'", "b'TipicoTim'", "b'sensinho82'",
#        "b'Train63'", "b'chaosqueen64'", "b'h_hendrich'",
#        "b'Scofield1708'", "b'botha_baas'", "b'Fuchshoernchen'",
#        "b'Schietweer'"], dtype=object)

# %%
#Clean the text and username using functions in order to remove some specific characters

def cleanTxt(text):
    text = re.sub(r'@[A-Za-z0-9\_]+','',text) #Removes @ mentions
    text = re.sub(r'_[A-Za-z0-9\_]+','',text)
    text = re.sub(r'#','', text)
    text = re.sub(r'RT[\s]+','',text)
    text = re.sub(r'https?:\/\/\S+','',text) # Remove the hyper link
    return text

def cleanUsername(name):
    name = re.sub(r"b\'",'',name)
    name = re.sub(r"\'",'',name)
    return name

# %%
#Apply the clean Text function to the column tweet
df['tweet']=df['tweet'].apply(cleanTxt)

# %%
#Apply the cleanUsername function to the column User
df['User']=df['User'].apply(cleanUsername)

# %%
#Translate the tweets to english using GoogleTranslator in order to execute the Sentiment analysis in the next step
df['translated_tweet'] = df['tweet'].apply(lambda x: GoogleTranslator(source='de', target='en').translate(x))

# %%
#Initialize the english stopwords in order to avoid bias in the next steps where the tweets are analyzed
english_stopwords = stopwords.words('english')
#Initialize the CountVectorizer
vect = CountVectorizer(stop_words = english_stopwords)

# %%
#Remove all stopwords from all the translated tweets
df['tweet_without_stopwords'] = df['translated_tweet'].apply(lambda x: ' '.join([word for word in x.split() if word not in (english_stopwords)]))

# %%
#Save dataframe as csv file
df.to_csv('SGE_prepared.csv')
